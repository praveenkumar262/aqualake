# %% [markdown]
# # Truncate and Load
# ### Create Database and Table in Databricks
# ###   One-Time Setup: Database & Table Creation

# %%
# Define Catalog & Database
catalog_name = "podlakehousedemo"
database_name = "Aqualake_truncate_load"
table_name = "Customers"

# Ensure database exists
spark.sql(f"CREATE DATABASE IF NOT EXISTS {catalog_name}.{database_name}")

# Create Delta table (if it doesn’t exist)
spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{database_name}.{table_name} (
        CustomerID STRING,
        FirstName STRING,
        MiddleInitial STRING,
        LastName STRING,
        CityID STRING,
        Address STRING
    ) USING DELTA
""")
print(f"✅ Table {catalog_name}.{database_name}.{table_name} is ready!")
# Out:
# ✅ Table podlakehousedemo.Aqualake_truncate_load.Customers is ready!

# %% [markdown]
# ### Configure Azure Blob Storage Access (SAS Token)

# %%
# Set up Azure Blob Storage access using SAS Token
spark.conf.set(
    "fs.azure.account.auth.type.demolakehouse.dfs.core.windows.net", 
    "SAS"
)
spark.conf.set(
    "fs.azure.sas.token.provider.type.demolakehouse.dfs.core.windows.net", 
    "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider"
)
spark.conf.set(
    "fs.azure.sas.fixed.token.demolakehouse.dfs.core.windows.net", 
    "sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2025-03-25T19:05:29Z&st=2025-03-25T11:05:29Z&spr=https&sig=UIVR2nhtuNzAMsqJktqn68NLFuRYUwVNqwjK5gH85ts%3D"
)
print("✅ Azure Storage SAS Token Configured")

# Define the Azure Blob Storage path using abfss protocol
adls_path = "abfss://poddemo@demolakehouse.dfs.core.windows.net/Aqualake_Sourcefiles_TL/"

# Read data from the specified path
try:
    df = spark.read.format("csv").option("header", "true").load(adls_path)
    print("✅ Data read successfully!")
    display(df)
except Exception as e:
    print("❌ Error reading data:", str(e))
# Out:
# ✅ Azure Storage SAS Token Configured
# ✅ Data read successfully!
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>FirstName</th><th>MiddleInitial</th><th>LastName</th><th>CityID</th><th>Address</th></tr></thead><tbody><tr><td>2194</td><td>Walter</td><td>F</td><td>Sellers</td><td>63</td><td>22 Hague Street</td></tr><tr><td>2195</td><td>Marie</td><td>F</td><td>Sharp</td><td>16</td><td>20 Oak Street</td></tr><tr><td>2196</td><td>Kari</td><td>C</td><td>Cain</td><td>28</td><td>99 South Rocky Second Road</td></tr><tr><td>2197</td><td>Tricia</td><td>F</td><td>Sheppard</td><td>44</td><td>80 Cowley Parkway</td></tr><tr><td>2198</td><td>Brendan</td><td>F</td><td>Glenn</td><td>55</td><td>40 Rocky Old Street</td></tr><tr><td>2199</td><td>Gerard</td><td>I</td><td>Conrad</td><td>49</td><td>202 Cowley Drive</td></tr><tr><td>2200</td><td>Jill</td><td>K</td><td>Sherman</td><td>81</td><td>66 North Green Hague Avenue</td></tr><tr><td>2201</td><td>Theresa</td><td>T</td><td>Barker</td><td>85</td><td>36 Oak Street</td></tr><tr><td>2202</td><td>Valerie</td
td>5</td><td>744 Oak Freeway</td></tr><tr><td>2228</td><td>Dale</td><td>T</td><td>Barron</td><td>60</td><td>939 White Clarendon Way</td></tr><tr><td>2229</td><td>Andrew</td><td>I</td><td>Herrera</td><td>86</td><td>21 Green Old Drive</td></tr><tr><td>2230</td><td>Roberta</td><td>P</td><td>Powell</td><td>7</td><td>584 Rocky Clarendon Blvd.</td></tr><tr><td>2231</td><td>Clifton</td><td>F</td><td>Hooper</td><td>70</td>< ...

# %% [markdown]
# ### Read Data from Azure Blob Storage

# %%
# Read the CSV file from Azure Blob Storage
df = spark.read.format("csv").option("header", "true").load(adls_path)

# Write to Delta Table
df.write.format("delta").mode("append").saveAsTable(f"{catalog_name}.{database_name}.{table_name}")

print(f"✅ Data loaded into {catalog_name}.{database_name}.{table_name} successfully!")
# Out:
# ✅ Data loaded into podlakehousedemo.Aqualake_truncate_load.Customers successfully!

# %% [markdown]
# ### Truncate Existing Data Before Loading New Data

# %%
# Truncate the table
spark.sql(f"TRUNCATE TABLE {catalog_name}.{database_name}.{table_name}")
print(f"✅ {table_name} table truncated successfully!")
# Out:
# ✅ Customers table truncated successfully!

# %%
# %sql
select count(*) from aqualake_truncate_load.customers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>2880</td></tr></tbody></table></div>

# %%
# Databricks Recurring Steps Script

# Step 1: Configure Azure Blob Storage Access using SAS Token
spark.conf.set(
    "fs.azure.account.auth.type.demolakehouse.dfs.core.windows.net", 
    "SAS"
)
spark.conf.set(
    "fs.azure.sas.token.provider.type.demolakehouse.dfs.core.windows.net", 
    "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider"
)
spark.conf.set(
    "fs.azure.sas.fixed.token.demolakehouse.dfs.core.windows.net", 
    "sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2025-03-25T19:05:29Z&st=2025-03-25T11:05:29Z&spr=https&sig=UIVR2nhtuNzAMsqJktqn68NLFuRYUwVNqwjK5gH85ts%3D"
)
print("✅ Azure Storage SAS Token Configured")

# Step 2: Define Azure Blob Storage Path
adls_path = "abfss://poddemo@demolakehouse.dfs.core.windows.net/Aqualake_Sourcefiles_TL/"

# Step 3: Read Data from Azure Blob Storage
try:
    df = spark.read.format("csv").option("header", "true").load(adls_path)
    source_count = df.count()
    print(f"✅ Data read successfully! Source Count: {source_count}")
    display(df)  # Display first few rows
except Exception as e:
    print("❌ Error reading data:", str(e))

# Step 4: Truncate Existing Data Before Loading New Data
spark.sql(f"TRUNCATE TABLE {catalog_name}.{database_name}.{table_name}")
print(f"✅ {table_name} table truncated successfully!")

# Step 5: Load Fresh Data into Delta Table
df.write.format("delta").mode("append").saveAsTable(f"{catalog_name}.{database_name}.{table_name}")

# Step 6: Validate the Load
target_count = spark.sql(f"SELECT COUNT(*) FROM {catalog_name}.{database_name}.{table_name}").collect()[0][0]
print(f"✅ Data loaded into {catalog_name}.{database_name}.{table_name} successfully!")
print(f"🔄 Validation: Source Count = {source_count}, Target Count = {target_count}")

# Step 7: Display Sample Records from Target Table
spark.sql(f"SELECT * FROM {catalog_name}.{database_name}.{table_name} LIMIT 10").show()
# Out:
# ✅ Azure Storage SAS Token Configured
# ✅ Data read successfully! Source Count: 2880
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th
tr><td>2216</td><td>Damian</td><td>R</td><td>Bradshaw</td><td>64</td><td>71 East New Boulevard</td></tr><tr><td>2217</td><td>Manuel</td><td>Z</td><td>Bright</td><td>51</td><td>55 Old Way</td></tr><tr><td>2218</td><td>Julie</td><td>B</td><td>Mcgrath</td><td>23</td><td>30 East Oak Road</td></tr><tr><td>2219</td><td>Kristi</td><td>Z</td><td>Downs</td><td>7</td><td>20 Nobel Way</td></tr><tr><td>2220</td><td>Freddie</td><td>L</td><td>Mc Lean</td><td>85</td><td>55 First Parkway</td></tr><tr><td>2221</td><td>Eli</td><td>E</td><td>Cowan</td><td>40</td><td>52 First Way</td></tr><tr><td>2222</td><td>Erin</td><td>J</td><td>Gordon</td><td>64</td><td>288 Rocky Cowley St.</td></tr><tr><td>2223</td><td>Randal</td><td>X</td><td>Buchanan</td><td>9</td><td>215 Nobel Blvd.</td></tr><tr><td>2224</td><td>Gretchen</td><td>Y</td><td>Cooke</td><td>6</td><td>60 Green Milton Freeway</td></tr><tr><td>2225</td><td>Arnold</td><td>U</td><td>Duffy</td><td>61</td><td>685 Hague Freeway</td></tr><tr><td>2226</td><td>Lynette</td><td>Z</td><td>Martinez</td><td>79</td><td>789 West Rocky Cowley Avenue</td></tr><tr><td>2227</td><td>Arnold</td><td>T</td><td>Peters</td><td>5</td><td>744 Oak Freeway</td></tr><tr><td>2228</td><td>Dale</td><td>T</td><td>Barron</td><td>60</td><td>939 White Clarendon Way</td></tr><tr><td>2229</td><td>Andrew</td><td>I</td><td>Herrera</td><td>86</td><td>21 Green Old Drive</td></tr><tr><td>2230</td><td>Roberta</td><td>P</td><td>Powell</td><td>7</td><td>584 Rocky Clarendon Blvd.</td></tr><tr><td>2231</td><td>Clifton</td><td>F</td><td>Hooper</td><td>70</td>< ...
# ✅ Customers table truncated successfully!
# ✅ Data loaded into podlakehousedemo.Aqualake_truncate_load.Customers successfully!
# 🔄 Validation: Source Count = 2880, Target Count = 2880
# +----------+---------+-------------+--------+------+--------------------+
# |CustomerID|FirstName|MiddleInitial|LastName|CityID|             Address|
# +----------+---------+-------------+--------+------+--------------------+
# |      2194|   Walter|            F| Sellers|    63|     22 Hague Street|
# |      2195|    Marie|            F|   Sharp|    16|       20 Oak Street|
# |      2196|     Kari|            C|    Cain|    28|99 South Rocky Se...|
# |      2197|   Tricia|            F|Sheppard|    44|   80 Cowley Parkway|
# |      2198|  Brendan|            F|   Glenn|    55| 40 Rocky Old Street|
# |      2199|   Gerard|            I|  Conrad|    49|    202 Cowley Drive|
# |      2200|     Jill|            K| Sherman|    81|66 North Green Ha...|
# |      2201|  Theresa|            T|  Barker|    85|       36 Oak Street|
# |      2202|  Valerie|            K| Sanford|    43|    12 Clarendon Way|
# |      2203|   Alison|            T|  Guzman|     4|154 North Milton ...|
# +----------+---------+-------------+--------+------+--------------------+
